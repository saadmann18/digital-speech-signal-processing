# %% [markdown]
# ## Mike x cohen link
# ### https://www.youtube.com/playlist?list=PLn0OLiymPak2BYu--bR0ADNBJsC4kuRWs
#
# ## neso academy link
# ### https://www.youtube.com/watch?v=IKJuvJGjADY&list=PLBlnK6fEyqRhG6s3jYIU48CqsT5cyiDTO&index=198

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact
plt.rcParams['figure.figsize'] = (15, 15)

# %%
f_disp = 16000
T_m = 1000/f_disp   #T_m = 0.0625
alpha = 25/T_m #what is alpha

t = np.r_[-T_m/2:T_m/2+1/f_disp:1/f_disp]   #-0.03125 : 0.03125 : 1/16000
x_t = np.exp(-alpha*np.abs(t))

omega = 2*np.pi*np.r_[-f_disp/10:f_disp/10:0.1]
X_w = 2*alpha/(alpha**2 + omega**2)

# %%
T_m
# Out:
# 0.0625

# %%
alpha
# Out:
# 400.0

# %%
t
# Out:
# array([-0.03125  , -0.0311875, -0.031125 , ...,  0.031125 ,  0.0311875,
#         0.03125  ])
